# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Anshuman**

# %% [markdown]
# Automobile Engineer

# %% [markdown]
# *Being good at Data Science will help me in my day to day work. Hence, I am keen on learning this subject*

# %% [markdown]
# ### 1+1 operation

# %%
1+1
# Out:
# 2

# %% [markdown]
# ~~Scratch this.~~
#
# * Bullet list 1
# * Bullet list 2
# * Bullet list 3
# 1. Numbered list 1
# 2. Numbered list 2
# 3. Numbered list 3
